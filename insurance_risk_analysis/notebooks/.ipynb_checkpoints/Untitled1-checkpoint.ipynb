# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Creating path variable to read train data
INTERIM_DATA_PATH = os.path.abspath(os.path.join(os.getcwd(),os.path.pardir,'data','interim','train_set.csv'))

# %%
# Creating path variable to read train data
PREPROCESSING_DIRECTORY = os.path.abspath(os.path.join(os.getcwd(),os.path.pardir,'src','data'))

# %%
df = pd.read_csv(INTERIM_DATA_PATH)

# %%
import scipy.stats as stats
from scipy.stats import chi2_contingency

class ChiSquare:
    def __init__(self, dataframe):
        self.df = dataframe
        self.p = None #P-Value
        self.chi2 = None #Chi Test Statistic
        self.dof = None
        
        self.dfObserved = None
        self.dfExpected = None
        self.noImportantCols = []
        
    def _print_chisquare_result(self, colX, alpha):
        result = ""
        if self.p<alpha:
            result="{0} is IMPORTANT for Prediction".format(colX)
        else:
            result="{0} is NOT an important predictor. (Discard {0} from model)".format(colX)
            self.noImportantCols.append(colX)

        print(result)
        
    def TestIndependence(self,colX,colY, alpha=0.05):
        X = self.df[colX].astype(str)
        Y = self.df[colY].astype(str)
        
        self.dfObserved = pd.crosstab(Y,X) 
        chi2, p, dof, expected = stats.chi2_contingency(self.dfObserved.values)
        self.p = p
        self.chi2 = chi2
        self.dof = dof 
        
        self.dfExpected = pd.DataFrame(expected, columns=self.dfObserved.columns, index = self.dfObserved.index)
        
        self._print_chisquare_result(colX,alpha)

# %%
df.drop(['Unnamed: 0'],axis=1, inplace =True)

# %%
X = df.drop([ 'Claim'], axis=1)
ct = ChiSquare(df)
for c in X.columns:
    ct.TestIndependence(c, 'Claim')
# Out:
# Agency is IMPORTANT for Prediction
# Agency Type is IMPORTANT for Prediction
# Distribution Channel is IMPORTANT for Prediction
# Duration is IMPORTANT for Prediction
# Net Sales is IMPORTANT for Prediction
# Commision (in value) is IMPORTANT for Prediction
# Age is IMPORTANT for Prediction
# Product Name_1 way Comprehensive Plan is IMPORTANT for Prediction
# Product Name_2 way Comprehensive Plan is IMPORTANT for Prediction
# Product Name_24 Protect is NOT an important predictor. (Discard Product Name_24 Protect from model)
# Product Name_Annual Gold Plan is IMPORTANT for Prediction
# Product Name_Annual Silver Plan is IMPORTANT for Prediction
# Product Name_Annual Travel Protect Gold is IMPORTANT for Prediction
# Product Name_Annual Travel Protect Platinum is NOT an important predictor. (Discard Product Name_Annual Travel Protect Platinum from model)
# Product Name_Annual Travel Protect Silver is NOT an important predictor. (Discard Product Name_Annual Travel Protect Silver from model)
# Product Name_Basic Plan is IMPORTANT for Prediction
# Product Name_Bronze Plan is IMPORTANT for Prediction
# Product Name_Cancellation Plan is IMPORTANT for Prediction
# Product Name_Child Comprehensive Plan is IMPORTANT for Prediction
# Product Name_Comprehensive Plan is NOT an important predictor. (Discard Product Name_Comprehensive Plan from model)
# Product Name_Gold Plan is IMPORTANT for Prediction
# Product Name_Individual Comprehensive Plan is IMPORTANT for Prediction
# Product Name_Premier Plan is NOT an important predictor. (Discard Product Name_Premier Plan from model)
# Product Name_Rental Vehicle Excess Insurance is IMPORTANT for Prediction
# Product Name_Silver Plan is IMPORTANT for Prediction
# Product Name_Single Trip Travel Protect Gold is IMPORTANT for Prediction
# Product Name_Single Trip Travel Protect Platinum is IMPORTANT for Prediction
# Product Name_Single Trip Travel Protect Silver is NOT an important predictor. (Discard Product Name_Single Trip Travel Protect Silver from model)
# Product Name_Spouse or Parents Comprehensive Plan is NOT an important predictor. (Discard Product Name_Spouse or Parents Comprehensive Plan from model)
# Product Name_Ticket Protector is NOT an important predictor. (Discard Product Name_Ticket Protector from model)
# Product Name_Travel Cruise Protect is NOT an important predictor. (Discard Product Name_Travel Cruise Protect from model)
# Product Name_Travel Cruise Protect Family is IMPORTANT for Prediction
# Product Name_Value Plan is IMPORTANT for Prediction
# Destination_ARGENTINA is NOT an important predictor. (Discard Destination_ARGENTINA from model)
# Destination_AUSTRALIA is IMPORTANT for Prediction
# Destination_AUSTRIA is NOT an important predictor. (Discard Destination_AUSTRIA from model)
# Destination_AZERBAIJAN is NOT an important predictor. (Discard Destination_AZERBAIJAN from model)
# Destination_BAHRAIN is NOT an important predictor. (Discard Destination_BAHRAIN from model)
# Destination_BANGLADESH is NOT an important predictor. (Discard Destination_BANGLADESH from model)
# Destination_BARBADOS is IMPORTANT for Prediction
# Destination_BELARUS is IMPORTANT for Prediction
# Destination_BELGIUM is NOT an important predictor. (Discard Destination_BELGIUM from model)
# Destination_BHUTAN is IMPORTANT for Prediction
# Destination_BOLIVIA is NOT an important predictor. (Discard Destination_BOLIVIA from model)
# Destination_BOSNIA AND HERZEGOVINA is IMPORTANT for Prediction
# Destination_BOTSWANA is IMPORTANT for Prediction
# Destination_BRAZIL is NOT an important predictor. (Discard Destination_BRAZIL from model)
# Destination_BRUNEI DARUSSALAM is NOT an important predictor. (Discard Destination_BRUNEI DARUSSALAM from model)
# Destination_BULGARIA is NOT an important predictor. (Discard Destination_BULGARIA from model)
# Destination_CAMBODIA is NOT an important predictor. (Discard Destination_CAMBODIA from model)
# Destination_CAMEROON is IMPORTANT for Prediction
# Destination_CANADA is NOT an important predictor. (Discard Destination_CANADA from model)
# Destination_CHILE is NOT an important predictor. (Discard Destination_CHILE from model)
# Destination_CHINA is IMPORTANT for Prediction
# Destination_COLOMBIA is NOT an important predictor. (Discard Destination_COLOMBIA from model)
# Destination_COSTA RICA is NOT an important predictor. (Discard Destination_COSTA RICA from model)
# Destination_CROATIA is NOT an important predictor. (Discard Destination_CROATIA from model)
# Destination_CYPRUS is NOT an important predictor. (Discard Destination_CYPRUS from model)
# Destination_CZECH REPUBLIC is NOT an important predictor. (Discard Destination_CZECH REPUBLIC from model)
# Destination_DENMARK is NOT an important predictor. (Discard Destination_DENMARK from model)
# Destination_ECUADOR is NOT an important predictor. (Discard Destination_ECUADOR from model)
# Destination_EGYPT is NOT an important predictor. (Discard Destination_EGYPT from model)
# Destination_ESTONIA is NOT an important predictor. (Discard Destination_ESTONIA from model)
# Destination_ETHIOPIA is IMPORTANT for Prediction
# Destination_FAROE ISLANDS is IMPORTANT for Prediction
# Destination_FIJI is NOT an important predictor. (Discard Destination_FIJI from model)
# Destination_FINLAND is NOT an important predictor. (Discard Destination_FINLAND from model)
# Destination_FRANCE is NOT an important predictor. (Discard Destination_FRANCE from model)
# Destination_GEORGIA is NOT an important predictor. (Discard Destination_GEORGIA from model)
# Destination_GERMANY is NOT an important predictor. (Discard Destination_GERMANY from model)
# Destination_GHANA is NOT an important predictor. (Discard Destination_GHANA from model)
# Destination_GREECE is NOT an important predictor. (Discard Destination_GREECE from model)
# Destination_GUAM is NOT an important predictor. (Discard Destination_GUAM from model)
# Destination_GUATEMALA is IMPORTANT for Prediction
# Destination_GUINEA is IMPORTANT for Prediction
# Destination_GUINEA-BISSAU is IMPORTANT for Prediction
# Destination_GUYANA is IMPORTANT for Prediction
# Destination_HONG KONG is IMPORTANT for Prediction
# Destination_HUNGARY is NOT an important predictor. (Discard Destination_HUNGARY from model)
# Destination_ICELAND is NOT an important predictor. (Discard Destination_ICELAND from model)
# Destination_INDIA is IMPORTANT for Prediction
# Destination_INDONESIA is IMPORTANT for Prediction
# Destination_IRAN, ISLAMIC REPUBLIC OF is IMPORTANT for Prediction
# Destination_IRELAND is NOT an important predictor. (Discard Destination_IRELAND from model)
# Destination_ISRAEL is NOT an important predictor. (Discard Destination_ISRAEL from model)
# Destination_ITALY is NOT an important predictor. (Discard Destination_ITALY from model)
# Destination_JAMAICA is IMPORTANT for Prediction
# Destination_JAPAN is IMPORTANT for Prediction
# Destination_JORDAN is NOT an important predictor. (Discard Destination_JORDAN from model)
# Destination_KAZAKHSTAN is NOT an important predictor. (Discard Destination_KAZAKHSTAN from model)
# Destination_KENYA is NOT an important predictor. (Discard Destination_KENYA from model)
# Destination_KOREA, DEMOCRATIC PEOPLE'S REPUBLIC OF is IMPORTANT for Prediction
# Destination_KOREA, REPUBLIC OF is NOT an important predictor. (Discard Destination_KOREA, REPUBLIC OF from model)
# Destination_KUWAIT is NOT an important predictor. (Discard Destination_KUWAIT from model)
# Destination_KYRGYZSTAN is NOT an important predictor. (Discard Destination_KYRGYZSTAN from model)
# Destination_LAO PEOPLE'S DEMOCRATIC REPUBLIC is NOT an important predictor. (Discard Destination_LAO PEOPLE'S DEMOCRATIC REPUBLIC from model)
# Destination_LATVIA is IMPORTANT for Prediction
# Destination_LEBANON is NOT an important predictor. (Discard Destination_LEBANON from model)
# Destination_LIBYAN ARAB JAMAHIRIYA is IMPORTANT for Prediction
# Destination_LITHUANIA is IMPORTANT for Prediction
# Destination_LUXEMBOURG is NOT an important predictor. (Discard Destination_LUXEMBOURG from model)
# Destination_MACAO is NOT an important predictor. (Discard Destination_MACAO from model)
# Destination_MACEDONIA, THE FORMER YUGOSLAV REPUBLIC OF is IMPORTANT for Prediction
# Destination_MALAYSIA is IMPORTANT for Prediction
# Destination_MALDIVES is NOT an important predictor. (Discard Destination_MALDIVES from model)
# Destination_MALI is IMPORTANT for Prediction
# Destination_MALTA is NOT an important predictor. (Discard Destination_MALTA from model)
# Destination_MAURITIUS is NOT an important predictor. (Discard Destination_MAURITIUS from model)
# Destination_MEXICO is NOT an important predictor. (Discard Destination_MEXICO from model)
# Destination_MOLDOVA, REPUBLIC OF is IMPORTANT for Prediction
# Destination_MONGOLIA is NOT an important predictor. (Discard Destination_MONGOLIA from model)
# Destination_MOROCCO is NOT an important predictor. (Discard Destination_MOROCCO from model)
# Destination_MYANMAR is IMPORTANT for Prediction
# Destination_NAMIBIA is IMPORTANT for Prediction
# Destination_NEPAL is NOT an important predictor. (Discard Destination_NEPAL from model)
# Destination_NETHERLANDS is NOT an important predictor. (Discard Destination_NETHERLANDS from model)
# Destination_NEW CALEDONIA is IMPORTANT for Prediction
# Destination_NEW ZEALAND is NOT an important predictor. (Discard Destination_NEW ZEALAND from model)
# Destination_NIGERIA is IMPORTANT for Prediction
# Destination_NORTHERN MARIANA ISLANDS is IMPORTANT for Prediction
# Destination_NORWAY is NOT an important predictor. (Discard Destination_NORWAY from model)
# Destination_OMAN is NOT an important predictor. (Discard Destination_OMAN from model)
# Destination_PAKISTAN is NOT an important predictor. (Discard Destination_PAKISTAN from model)
# Destination_PANAMA is IMPORTANT for Prediction
# Destination_PAPUA NEW GUINEA is NOT an important predictor. (Discard Destination_PAPUA NEW GUINEA from model)
# Destination_PERU is NOT an important predictor. (Discard Destination_PERU from model)
# Destination_PHILIPPINES is IMPORTANT for Prediction
# Destination_POLAND is NOT an important predictor. (Discard Destination_POLAND from model)
# Destination_PORTUGAL is NOT an important predictor. (Discard Destination_PORTUGAL from model)
# Destination_PUERTO RICO is IMPORTANT for Prediction
# Destination_QATAR is NOT an important predictor. (Discard Destination_QATAR from model)
# Destination_REPUBLIC OF MONTENEGRO is IMPORTANT for Prediction
# Destination_ROMANIA is NOT an important predictor. (Discard Destination_ROMANIA from model)
# Destination_RUSSIAN FEDERATION is NOT an important predictor. (Discard Destination_RUSSIAN FEDERATION from model)
# Destination_SAMOA is IMPORTANT for Prediction
# Destination_SAUDI ARABIA is NOT an important predictor. (Discard Destination_SAUDI ARABIA from model)
# Destination_SENEGAL is IMPORTANT for Prediction
# Destination_SERBIA is NOT an important predictor. (Discard Destination_SERBIA from model)
# Destination_SINGAPORE is IMPORTANT for Prediction
# Destination_SLOVENIA is NOT an important predictor. (Discard Destination_SLOVENIA from model)
# Destination_SOLOMON ISLANDS is IMPORTANT for Prediction
# Destination_SOUTH AFRICA is NOT an important predictor. (Discard Destination_SOUTH AFRICA from model)
# Destination_SPAIN is NOT an important predictor. (Discard Destination_SPAIN from model)
# Destination_SRI LANKA is NOT an important predictor. (Discard Destination_SRI LANKA from model)
# Destination_SWEDEN is NOT an important predictor. (Discard Destination_SWEDEN from model)
# Destination_SWITZERLAND is NOT an important predictor. (Discard Destination_SWITZERLAND from model)
# Destination_TAIWAN, PROVINCE OF CHINA is NOT an important predictor. (Discard Destination_TAIWAN, PROVINCE OF CHINA from model)
# Destination_TAJIKISTAN is IMPORTANT for Prediction
# Destination_TANZANIA, UNITED REPUBLIC OF is NOT an important predictor. (Discard Destination_TANZANIA, UNITED REPUBLIC OF from model)
# Destination_THAILAND is IMPORTANT for Prediction
# Destination_TIBET is IMPORTANT for Prediction
# Destination_TRINIDAD AND TOBAGO is NOT an important predictor. (Discard Destination_TRINIDAD AND TOBAGO from model)
# Destination_TUNISIA is NOT an important predictor. (Discard Destination_TUNISIA from model)
# Destination_TURKEY is NOT an important predictor. (Discard Destination_TURKEY from model)
# Destination_UGANDA is IMPORTANT for Prediction
# Destination_UKRAINE is NOT an important predictor. (Discard Destination_UKRAINE from model)
# Destination_UNITED ARAB EMIRATES is NOT an important predictor. (Discard Destination_UNITED ARAB EMIRATES from model)
# Destination_UNITED KINGDOM is NOT an important predictor. (Discard Destination_UNITED KINGDOM from model)
# Destination_UNITED STATES is NOT an important predictor. (Discard Destination_UNITED STATES from model)
# Destination_URUGUAY is IMPORTANT for Prediction
# Destination_UZBEKISTAN is NOT an important predictor. (Discard Destination_UZBEKISTAN from model)
# Destination_VANUATU is IMPORTANT for Prediction
# Destination_VENEZUELA is IMPORTANT for Prediction
# Destination_VIET NAM is IMPORTANT for Prediction
# Destination_VIRGIN ISLANDS, U.S. is IMPORTANT for Prediction
# Destination_ZAMBIA is IMPORTANT for Prediction
# Destination_ZIMBABWE is IMPORTANT for Prediction

# %% [markdown]
# **Insights**
# There are 91 columns which are not important according to Chi square test

# %%
noImportantCols=pd.DataFrame(ct.noImportantCols)

# %%
noImportantCols.to_csv(os.path.join(PREPROCESSING_DIRECTORY,'noImoportantCols.csv'))
